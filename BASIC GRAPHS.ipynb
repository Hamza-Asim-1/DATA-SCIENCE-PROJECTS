# %% [markdown]
# In \[1\]:
#
#         import pandas as pd
#         import numpy as np
#         import matplotlib.pyplot as plt
#         import seaborn as sns
#         import plotly.express as px
#
# In \[2\]:
#
#     df = pd.read_csv("jobs_in_data.csv")
#
# In \[3\]:
#
#     df.head()
#
# Out\[3\]:
#
# |     | work_year | job_title            | job_category                   | salary_currency | salary | salary_in_usd | employee_residence | experience_level | employment_type | work_setting | company_location | company_size |
# |-----|-----------|----------------------|--------------------------------|-----------------|--------|---------------|--------------------|------------------|-----------------|--------------|------------------|--------------|
# | 0   | 2023      | Data DevOps Engineer | Data Engineering               | EUR             | 88000  | 95012         | Germany            | Mid-level        | Full-time       | Hybrid       | Germany          | L            |
# | 1   | 2023      | Data Architect       | Data Architecture and Modeling | USD             | 186000 | 186000        | United States      | Senior           | Full-time       | In-person    | United States    | M            |
# | 2   | 2023      | Data Architect       | Data Architecture and Modeling | USD             | 81800  | 81800         | United States      | Senior           | Full-time       | In-person    | United States    | M            |
# | 3   | 2023      | Data Scientist       | Data Science and Research      | USD             | 212000 | 212000        | United States      | Senior           | Full-time       | In-person    | United States    | M            |
# | 4   | 2023      | Data Scientist       | Data Science and Research      | USD             | 93300  | 93300         | United States      | Senior           | Full-time       | In-person    | United States    | M            |
#
# In \[10\]:
#
#     # Line graph
#     plt.figure(figsize=(10, 6))
#     sns.lineplot(x='job_title', y='salary_in_usd', data=df, marker='o')
#     plt.title('Salary by Job Title (Line Graph)')
#     plt.xlabel('Job Title')
#     plt.ylabel('Salary (USD)')
#     plt.xticks(rotation=90)
#     plt.tight_layout()
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[11\]:
#
#     # Area graph
#     plt.figure(figsize=(10, 6))
#     sns.lineplot(x='job_title', y='salary_in_usd', data=df, marker='o', ci=None)
#     plt.fill_between(df['job_title'], df['salary_in_usd'], alpha=0.2)
#     plt.title('Salary by Job Title (Area Graph)')
#     plt.xlabel('Job Title')
#     plt.ylabel('Salary (USD)')
#     plt.xticks(rotation=90)
#     plt.tight_layout()
#     plt.show()
#
#     C:\Users\dell\AppData\Local\Temp\ipykernel_14072\62271673.py:3: FutureWarning:
#
#     The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#       sns.lineplot(x='job_title', y='salary_in_usd', data=df, marker='o', ci=None)
#
# ![](data:image/png;base64,...)
#
# In \[6\]:
#
#     # Histogram
#     plt.figure(figsize=(10, 6))
#     sns.histplot(df['salary_in_usd'], bins=10, kde=True)
#     plt.title('Salary Distribution (Histogram)')
#     plt.xlabel('Salary (USD)')
#     plt.ylabel('Frequency')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[12\]:
#
#     # Bar graph
#     plt.figure(figsize=(10, 6))
#     sns.barplot(x='job_title', y='salary_in_usd', data=df)
#     plt.title('Average Salary by Job Title (Bar Graph)')
#     plt.xlabel('Job Title')
#     plt.ylabel('Average Salary (USD)')
#     plt.xticks(rotation=90)
#     plt.tight_layout()
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[14\]:
#
#     #Pie chart
#     # Job category data
#     job_categories = ['Data Engineering', 'Data Architecture and Modeling', 'Data Science and Research', 'Machine Learning and AI', 'Leadership and Management', 'BI and Visualization']
#     counts = [10, 2, 12, 10, 2, 4]
#
#     # Create a pie chart
#     plt.figure(figsize=(8, 8))
#     plt.pie(counts, labels=job_categories, autopct='%1.1f%%', startangle=140)
#     plt.title('Distribution of Job Categories')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[ \]:
