# %% [markdown]
# HAMZA ASIM
# L1F22BSDS0031
#
# # HEART ATTACK ANALYSIS AND PREDICTION<a href="#HEART-ATTACK-ANALYSIS-AND-PREDICTION" class="anchor-link">¶</a>
#
# The provided dataset contains information related to various attributes
# that are potentially associated with heart health, such as age, sex,
# chest pain type, resting blood pressure, cholesterol levels, fasting
# blood sugar, resting electrocardiographic results, maximum heart rate
# achieved, exercise-induced angina, ST depression induced by exercise
# relative to rest, slope of the peak exercise ST segment, number of major
# vessels colored by fluoroscopy, thalassemia, and the output indicating
# the presence or absence of a heart attack.
#
# To perform exploratory data analysis (EDA) and subsequent predictive
# modeling, I begin by exploring summary statistics, identifying patterns,
# and visualizing relationships between variables. Preprocess the data by
# handling missing values, encoding categorical variables, and scaling
# numerical features. Utilize techniques such as correlation analysis to
# understand variable relationships and feature importance. For machine
# learning, split the dataset into training and testing sets, choose a
# suitable algorithm (e.g., logistic regression, decision trees, or
# ensemble methods), train the model, and evaluate its performance using
# metrics like accuracy, precision, recall, and F1-score. Regularly
# validate and fine-tune the model to enhance its predictive capabilities
# for heart attack detection
#
# # ASSINGMENT \# 3<a href="#ASSINGMENT-%23-3" class="anchor-link">¶</a>
#
# In \[4\]:
#
#     #IMPORTING THE REQUIRED LIBRARIES FOR VISUALIZATIONS
#     import pandas as pd
#     import seaborn as sns
#     import matplotlib.pyplot as plt
#
# In \[5\]:
#
#     #IMPORTING THE DATASET
#     df=pd.read_csv('Heart.csv')
#     df.head()
#
# Out\[5\]:
#
# |     | age | sex | cp  | trtbps | chol | fbs | restecg | thalachh | exng | oldpeak | slp | caa | thall | output |
# |-----|-----|-----|-----|--------|------|-----|---------|----------|------|---------|-----|-----|-------|--------|
# | 0   | 63  | 1   | 3   | 145    | 233  | 1   | 0       | 150      | 0    | 2.3     | 0   | 0   | 1     | 1      |
# | 1   | 37  | 1   | 2   | 130    | 250  | 0   | 1       | 187      | 0    | 3.5     | 0   | 0   | 2     | 1      |
# | 2   | 41  | 0   | 1   | 130    | 204  | 0   | 0       | 172      | 0    | 1.4     | 2   | 0   | 2     | 1      |
# | 3   | 56  | 1   | 1   | 120    | 236  | 0   | 1       | 178      | 0    | 0.8     | 2   | 0   | 2     | 1      |
# | 4   | 57  | 0   | 0   | 120    | 354  | 0   | 1       | 163      | 1    | 0.6     | 2   | 0   | 2     | 1      |
#
# # META DATA<a href="#META-DATA" class="anchor-link">¶</a>
#
# Age : Age of the patient
#
# Sex : Sex of the patient
#
# exang: exercise induced angina (1 = yes; 0 = no)
#
# ca: number of major vessels (0-3)
#
# cp : Chest Pain type chest pain type
#
# Value 1: typical angina Value 2: atypical angina Value 3: non-anginal
# pain Value 4: asymptomatic trtbps : resting blood pressure (in mm Hg)
#
# chol : cholestoral in mg/dl fetched via BMI sensor
#
# fbs : (fasting blood sugar \> 120 mg/dl) (1 = true; 0 = false)
#
# rest_ecg : resting electrocardiographic results
#
# Value 0: normal Value 1: having ST-T wave abnormality (T wave inversions
# and/or ST elevation or depression of \> 0.05 mV) Value 2: showing
# probable or definite left ventricular hypertrophy by Estes' criteria
# thalach : maximum heart rate achieved
#
# target : 0= less chance of heart attack 1= more chance of heart attack
#
# In \[6\]:
#
#     #NEW COLOUM NAMES FOR BETTER UNDERSTANDING
#     new_column_names = ['Age', 'Sex', 'ChestPainType', 'RestingBloodPressure', 'Cholesterol', 'FastingBloodSugar', 'RestingECG', 'MaxHeartRate', 'ExerciseInducedAngina', 'STDepression', 'Slope', 'MajorVessels', 'Thalassemia', 'Output']
#     #IMPLEMENTING THE NEW NAMES
#     df.columns = new_column_names
#     #MODIFIED DATASET VIEW
#     df.head()
#
# Out\[6\]:
#
# |     | Age | Sex | ChestPainType | RestingBloodPressure | Cholesterol | FastingBloodSugar | RestingECG | MaxHeartRate | ExerciseInducedAngina | STDepression | Slope | MajorVessels | Thalassemia | Output |
# |-----|-----|-----|---------------|----------------------|-------------|-------------------|------------|--------------|-----------------------|--------------|-------|--------------|-------------|--------|
# | 0   | 63  | 1   | 3             | 145                  | 233         | 1                 | 0          | 150          | 0                     | 2.3          | 0     | 0            | 1           | 1      |
# | 1   | 37  | 1   | 2             | 130                  | 250         | 0                 | 1          | 187          | 0                     | 3.5          | 0     | 0            | 2           | 1      |
# | 2   | 41  | 0   | 1             | 130                  | 204         | 0                 | 0          | 172          | 0                     | 1.4          | 2     | 0            | 2           | 1      |
# | 3   | 56  | 1   | 1             | 120                  | 236         | 0                 | 1          | 178          | 0                     | 0.8          | 2     | 0            | 2           | 1      |
# | 4   | 57  | 0   | 0             | 120                  | 354         | 0                 | 1          | 163          | 1                     | 0.6          | 2     | 0            | 2           | 1      |
#
# # GRAPHS<a href="#GRAPHS" class="anchor-link">¶</a>
#
# # Correlation Heatmap<a href="#Correlation-Heatmap" class="anchor-link">¶</a>
#
# A correlation heatmap can show the correlation coefficients between
# different variables. This helps in identifying which features are more
# strongly correlated with the target variable
#
# In \[13\]:
#
#     heatmap = sns.heatmap(df.corr(), annot=True, cmap='coolwarm', linewidths=.5, fmt=".2f", cbar=False)
#
#     # Increase the size of the boxes
#     heatmap.set_xticklabels(heatmap.get_xticklabels(), size=12)
#     heatmap.set_yticklabels(heatmap.get_yticklabels(), size=12)
#
#     # Set the background color to black
#     plt.rcParams['axes.facecolor'] = 'black'
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# # BAR PLOT<a href="#BAR-PLOT" class="anchor-link">¶</a>
#
# A bar plot (or bar chart) is a type of data visualization that presents
# categorical data with rectangular bars. Each bar's length or height is
# proportional to the values it represents
#
# In \[16\]:
#
#     sns.set(style="whitegrid")
#
#     # Create a bar plot
#     plt.figure(figsize=(12, 6))
#     sns.countplot(x='Age', hue='Output', data=df, palette='pastel')
#
#     # Customize the plot
#     plt.title('Heart Disease Presence by Age')
#     plt.xlabel('Age')
#     plt.ylabel('Count')
#     plt.legend(title='Output', labels=['No Heart Disease', 'Heart Disease'])
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# # SCATTER PLOT<a href="#SCATTER-PLOT" class="anchor-link">¶</a>
#
# This scatter plot will show if there's any correlation between
# cholesterol levels and the maximum heart rate achieved, with different
# colors indicating the presence or absence of heart disease (output).
#
# In \[24\]:
#
#     # Plotting the correlation between cholesterol and maximum heart rate
#     plt.figure(figsize=(10, 6))
#     sns.scatterplot(x='Cholesterol', y='MaxHeartRate', data=df, hue='Output', palette='coolwarm', alpha=0.8)
#     plt.title('Correlation between Cholesterol and Maximum Heart Rate')
#     plt.xlabel('Cholesterol')
#     plt.ylabel('Max Heart Rate')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# # COUNT PLOT<a href="#COUNT-PLOT" class="anchor-link">¶</a>
#
# The countplot helps visualize how different chest pain types are
# distributed and whether there's any noticeable pattern or association
# with the presence of heart disease
#
# In \[7\]:
#
#     # Mapping numerical values to names for chest pain types
#     cp_mapping = {
#         1: 'typical angina',
#         2: 'atypical angina',
#         3: 'non-anginal pain',
#         4: 'asymptomatic'
#     }
#
#     df['ChestPainType'] = df['ChestPainType'].map(cp_mapping)
#
#     # Plotting the distribution of chest pain types
#     plt.figure(figsize=(10, 6))
#     sns.countplot(x='ChestPainType', data=df, hue='Output', palette='viridis')
#     plt.title('Distribution of Chest Pain Types')
#     plt.xlabel('Chest Pain Type')
#     plt.ylabel('Count')
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# # LINE PLOT<a href="#LINE-PLOT" class="anchor-link">¶</a>
#
# This line graph connects the mean maximum heart rate for each age group
#
# In \[10\]:
#
#     # Group by age and calculate the mean Thalachh for each age group
#     age_thalachh_mean = df.groupby('Age')['MaxHeartRate'].mean().reset_index()
#
#     # Line Graph: Age vs. Mean Maximum Heart Rate (Thalachh)
#     plt.figure(figsize=(10, 6))
#     sns.lineplot(x='Age', y='MaxHeartRate', data=age_thalachh_mean, marker='o', color='blue', label='Mean Thalachh')
#     plt.title('Age vs. Mean Maximum Heart Rate (Thalachh)')
#     plt.xlabel('Age')
#     plt.ylabel('Mean Maximum Heart Rate (Thalachh)')
#     plt.legend()
#     plt.show()
#
# ![](data:image/png;base64,...)
#
# In \[ \]:
