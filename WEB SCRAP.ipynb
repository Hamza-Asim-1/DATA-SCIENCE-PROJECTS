# %%
#HAMZA ASIM
#DAY#3

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
#defining the url
url='https://www.daftlogic.com/information-appliance-power-consumption.htm'

# %%
web=requests.get(url)
s=BeautifulSoup(web.content,'html.parser')

# %%
#finding the content using table id and storing the data into a dataframe
content = s.findAll(attrs = {'id': 'tblApp'})
df = pd.read_html(str(content))[0]
df
# Out:
#                           Appliance Minimum Maximum Standby  \
# 0    100W light bulb (Incandescent)    100W    100W      0W
# 1                    22 Inch LED TV     17W     17W    0.5W
# 2                     25" colour TV    150W    150W     NaN
# 3                    3" belt sander   1000W   1000W     NaN
# 4                    32 Inch LED TV     20W     60W      1W
# ..                              ...     ...     ...     ...
# 151                    WiFi Booster      1W      2W     NaN
# 152                     WiFi Router      4W     10W      4W
# 153          Window Air Conditioner    500W   1500W     NaN
# 154        Wine cooler (18 bottles)     83W     83W      0W
# 155                        Xbox One     50W    110W     14W
#
#                                   Other Name(s) References Notes
# 0                                           NaN        [1]   NaN
# 1                                           NaN        NaN   NaN
# ...

# %%
#converting dataframe to csv file
df.to_csv('appliances.csv')

# %%
#using pandas to read from the created csv to show contents
data = pd.read_csv('appliances.csv')
data.head(10)
# Out:
#    Unnamed: 0                       Appliance Minimum Maximum Standby  \
# 0           0  100W light bulb (Incandescent)    100W    100W      0W
# 1           1                  22 Inch LED TV     17W     17W    0.5W
# 2           2                   25" colour TV    150W    150W     NaN
# 3           3                  3" belt sander   1000W   1000W     NaN
# 4           4                  32 Inch LED TV     20W     60W      1W
# 5           5                  42 Inch LED TV     58W     60W    0.3W
# 6           6               42 Inch Plasma TV    450W    600W     NaN
# 7           7                  46 Inch LED TV     60W     70W      1W
# 8           8                  49 Inch LED TV     85W     85W      1W
# 9           9                  55 Inch LED TV    116W    116W    0.5W
#
#   Other Name(s) References Notes
# 0           NaN        [1]   NaN
# 1           NaN        NaN   NaN
# 2           NaN        NaN   NaN
# 3           NaN        NaN   NaN
# ...
